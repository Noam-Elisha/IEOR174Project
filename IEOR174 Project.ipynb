# %%
import random
import numpy as np
import csv

# %%
import csv
with open('GeneralData.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
# Out:
# {'Airport': '', 'Terminal': '', 'Date': '', 'Hour': '', 'U.S. Citizen': '', '': '', 'Non U.S. Citizen': '', 'All': 'Wait Times'}
# {'Airport': '', 'Terminal': '', 'Date': '', 'Hour': '', 'U.S. Citizen': 'Average Wait', '': 'Booths', 'Non U.S. Citizen': 'Average Wait', 'All': 'Average Wait'}
# {'Airport': '', 'Terminal': '', 'Date': '', 'Hour': '', 'U.S. Citizen': 'Time', '': '', 'Non U.S. Citizen': 'Time', 'All': 'Time'}
# {'Airport': 'SFO', 'Terminal': 'Terminal A', 'Date': '10/3/2019', 'Hour': '0000 - 0100', 'U.S. Citizen': '4', '': '5', 'Non U.S. Citizen': '12', 'All': '8'}
# {'Airport': 'SFO', 'Terminal': 'Terminal A', 'Date': '10/3/2019', 'Hour': '0900 - 1000', 'U.S. Citizen': '12', '': '17', 'Non U.S. Citizen': '20', 'All': '17'}
# {'Airport': 'SFO', 'Terminal': 'Terminal A', 'Date': '10/3/2019', 'Hour': '1000 - 1100', 'U.S. Citizen': '11', '': '18', 'Non U.S. Citizen': '24', 'All': '21'}
# ...
